# %%
intents = {
    "intents": [
        {
            "tag": "greeting",
            "patterns": ["Hi", "Hello", "Hey", "Good morning", "Good evening"],
            "responses": [
                "Hello! How can I assist you?",
                "Hi there! What can I do for you?"
            ]
        },
        {
            "tag": "goodbye",
            "patterns": ["Bye", "Exit", "Quit", "See you later"],
            "responses": [
                "Goodbye! Have a nice day.",
                "See you soon!"
            ]
        },
        {
            "tag": "thanks",
            "patterns": ["Thanks", "Thank you", "Much appreciated"],
            "responses": [
                "You're welcome!",
                "Happy to help!"
            ]
        },
        {
            "tag": "about",
            "patterns": [
                "Who are you?",
                "What is this chatbot?",
                "What can you do?"
            ],
            "responses": [
                "I am an intelligent chatbot built using machine learning techniques."
            ]
        },
        {
            "tag": "creator",
            "patterns": [
                "Who created you?",
                "Who made you?"
            ],
            "responses": [
                "I was created as part of a machine learning academic project."
            ]
        }
    ]
}
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['Hi', 'Hello', 'Hey', 'Good morning', 'Good evening'],
#    'responses': ['Hello! How can I assist you?',
#     'Hi there! What can I do for you?']},
#   {'tag': 'goodbye',
#    'patterns': ['Bye', 'Exit', 'Quit', 'See you later'],
#    'responses': ['Goodbye! Have a nice day.', 'See you soon!']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks', 'Thank you', 'Much appreciated'],
#    'responses': ["You're welcome!", 'Happy to help!']},
#   {'tag': 'about',
#    'patterns': ['Who are you?', 'What is this chatbot?', 'What can you do?'],
#    'responses': ['I am an intelligent chatbot built using machine learning techniques.']},
#   {'tag': 'creator',
#    'patterns': ['Who created you?', 'Who made you?'],
#    'responses': ['I was created as part of a machine learning academic project.']}]}
